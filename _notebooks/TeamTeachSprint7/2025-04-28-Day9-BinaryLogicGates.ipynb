# %% [raw]
# ---
# layout: page
# title: Yash Parikh - Lesson Day 9 - Binary and Logic Gates
# course: "compsci"
# week: 28
# type: hacks
# ---

# %% [markdown]
# ## Popcorn Hack 1
#
# 1. Yes, it is binary
# 2. No, it is not binary
# 3. Yes, it is binary

# %% [markdown]
# ## Popcorn Hack 2
#
# Example 1 (Adding):
# Binary Numbers: 101 + 110
#
# *The sum is 1011*
#
# Example 2 (Subtracting):
# Binary Numbers: 1101 - 1011
#
# *The difference is 10*
#
# Example 3 (Adding):
# Binary Numbers: 111 + 1001
#
# *The sum is 10000*

# %% [markdown]
# ## Homework Hack

# %%
AAA
